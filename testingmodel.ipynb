# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cnn=tf.keras.models.load_model("/content/trained_model.h5")
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from os import path
import cv2
image_path='/content/drive/MyDrive/fruit_veg_detector/archive (2)/test/cauliflower/Image_1.jpg'
img=cv2.imread(image_path)
plt.imshow(img)
plt.title('test image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image=tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr=tf.keras.preprocessing.image.img_to_array(image)
input_arr=np.array([input_arr])
prediction=cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %%
print(prediction[0])
print(max(prediction[0]))
# Out:
# [1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  3.3544242e-25 0.0000000e+00 7.5870568e-37 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0533119e-18
#  0.0000000e+00]
# 1.0

# %%
test_set.class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
result_index=np.where(prediction[0]==max(prediction[0]))
print(result_index)
# Out:
# (array([0]),)

# %%
test_set=tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/fruit_veg_detector/archive (2)/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,

)
# Out:
# Found 359 files belonging to 36 classes.

# %%
plt.imshow(img)
plt.title("Test image")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("img is {}".format(test_set.class_names[result_index[0][0]]))
# Out:
# img is apple
